# %%
import turtle
win = turtle.Screen()
win.title("pong by rofih")
win.bgcolor("black")
win.setup(width=400, height=300)
win.tracer(0)

#paddle A
paddle_a = turtle.Turtle()
paddle_a.speed(0)
paddle_a.shape("square")
paddle_a.color("white")
paddle_a.shapesize(stretch_wid=5, stretch_len=1)
paddle_a.penup()
paddle_a.goto(-150, 0)

#paddle B
paddle_b = turtle.Turtle()
paddle_b.speed(0)
paddle_b.shape("square")
paddle_b.color("white")
paddle_b.shapesize(stretch_wid=5, stretch_len=1)
paddle_b.penup()
paddle_b.goto(150, 0)
#Ball
ball = turtle.Turtle()
ball.speed(0)
ball.shape("square")
ball.color("white")
ball.penup()
ball.goto(0, 0)
def paddle_a_up():
    y = paddle_a.ycor()
    y -= 20
    paddle_a.sety(y)
def paddle_a_down():    
    y = paddle_a.ycor()
    y += 20
    paddle_a.sety(y)
def paddle_b_up():
    y = paddle_b.ycor()
    y -= 20
    paddle_b.sety(y)
def paddle_b_down():    
    y = paddle_b.ycor()
    y += 20
    paddle_b.sety(y)
#Keyboard binding
win.listen()
win.onkeypress(paddle_a_up, "w")
win.onkeypress(paddle_a_down, "z")
win.onkeypress(paddle_b_up, "a")
win.onkeypress(paddle_b_down, "d")
#main game loop
while True:
    win.update()
    
    #Move the ball
    ball.setx(ball.xcor() + ball.dx)
    ball.sety(ball.ycor() + ball.dy)
    #Border Checking
    if ball.ycor() > 190:
        ball.sety(190)
        ball.dy *= -1
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-2-d4af9ea62682> in <module>
#      54 #main game loop
#      55 while True:
# ---> 56     win.update()
#      57
#      58     #Move the ball
#
# ~\anaconda3\lib\turtle.py in update(self)
#    1302         self._tracing = True
#    1303         for t in self.turtles():
# -> 1304             t._update_data()
#    1305             t._drawturtle()
#    1306         self._tracing = tracing
#
# ~\anaconda3\lib\turtle.py in _update_data(self)
#    2645
#    2646     def _update_data(self):
# -> 2647         self.screen._incrementudc()
#    2648         if self.screen._updatecounter != 0:
#    2649             return
#
# ~\anaconda3\lib\turtle.py in _incrementudc(self)
#    1291         if not TurtleScreen._RUNNING:
#    1292             TurtleScreen._RUNNING = True
# -> 1293             raise Terminator
# ...

# %%
Weight = int(input('Weight: '))
unit = input('(L)bs or (K)g: ')
if unit.upper() == "L":
    converted = Weight * 0.45
    print(f'You are {converted} kilos')
else: 
    converted = Weight / 0.45
    print(f'You are {converted} pounds')
# Out:
# Weight: 50
# (L)bs or (K)g: K
# You are 111.11111111111111 pounds

# %%
print('================Welcome to my currency converter================\n================Here are the list of currency you can convert into================')
CURRENCY =["USD Dollar",
            "Naira",
            "Euro",
           "pounds",
            "Yen",
            "Swiss Franc",
            "SDR",
            "Waua",
            "Riyal",
            "SARand",
            "Danish Krona"]
print(CURRENCY)
IN = input('Enter the currency you are converting from: ')
OUT = input('Enter the currency you want into: ')
AMOUNT = int(input("Enter The Amount: "))
if IN.upper() == "DOLLAR" and OUT.upper() == "NAIRA":
    convert = AMOUNT * 410
    print(f'{convert} NAIRA')
elif IN.upper() == "NAIRA" and OUT.upper() == "DOLLAR":
    convert = AMOUNT / 410
    print(f'{convert} $')
elif IN.upper() == "POUNDS" and OUT.upper() == "NAIRA":
    convert = AMOUNT * 567
    print(f'{convert} NAIRA')
elif IN.upper() == "NAIRA" and OUT.upper() == "POUNDS":
    convert = AMOUNT / 567
    print(f'{convert} POUNDS')
elif IN.upper() == "EURO" and OUT.upper() == "NAIRA":
    convert = AMOUNT * 486
    print(f'{convert} NAIRA')
elif IN.upper() == "NAIRA" and OUT.upper() == "EURO":
    convert = AMOUNT / 486
    print(f'{convert} EURO')
elif IN.upper() == "YEN" and OUT.upper() == "NAIRA":
    convert = AMOUNT * 3.7
    print(f'{convert} NAIRA')
elif IN.upper() == "NAIRA" and OUT.upper() == "YEN":
    convert = AMOUNT / 3.7
    print(f'{convert} YEN')
elif IN.upper() == "SWISS" and OUT.upper() == "NAIRA":
    convert = AMOUNT * 442
    print(f'{convert} NAIRA')
elif IN.upper() == "NAIRA" and OUT.upper() == "SWISS":
    convert = AMOUNT / 442
    print(f'{convert} SWISS')
elif IN.upper() == "SDR" and OUT.upper() == "NAIRA":
    convert = AMOUNT * 583
    print(f'{convert} NAIRA')
elif IN.upper() == "NAIRA" and OUT.upper() == "SDR":
    convert = AMOUNT / 583
    print(f'{convert} SDR')
elif IN.upper() == "WAUA" and OUT.upper() == "NAIRA":
    convert = AMOUNT * 584
    print(f'{convert} NAIRA')
elif IN.upper() == "NAIRA" and OUT.upper() == "WAUA":
    convert = AMOUNT / 584
    print(f'{convert} WAUA')
elif IN.upper() == "RIYAL" and OUT.upper() == "NAIRA":
    convert = AMOUNT * 110
    print(f'{convert} NAIRA')
elif IN.upper() == "NAIRA" and OUT.upper() == "RIYAL":
    convert = AMOUNT / 110
    print(f'{convert} RIYAL') 
elif IN.upper() == "RAND" and OUT.upper() == "NAIRA":
    convert = AMOUNT * 29
    print(f'{convert} NAIRA')
elif IN.upper() == "NAIRA" and OUT.upper() == "RAND":
    convert = AMOUNT / 29
    print(f'{convert} RAND')
elif IN.upper() == "DANISH KRONA" and OUT.upper() == "NAIRA":
    convert = AMOUNT * 65
    print(f'{convert} DANISH KRONA')
elif IN.upper() == "NAIRA" and OUT.upper() == "DANISH KRONA":
    convert = AMOUNT / 65
    print(f'{convert} NAIRA')
elif IN.upper() == "DOLLAR" and OUT.upper() == "POUND":
    convert = AMOUNT * 0.72
    print(f'{convert} POUNDS')
elif IN.upper() == "POUNDS" and OUT.upper() == "DOLLAR":
    convert = AMOUNT / 0.72
    print(f'{convert} DOLLARS')
elif IN.upper() == "DOLLAR" and OUT.upper() == "SWISS":
    convert = AMOUNT * 0.91
    print(f'{convert} SWISS')
elif IN.upper() == "SWISS" and OUT.upper() == "DOLLAR":
    convert = AMOUNT / 0.91
    print(f'{convert} DOLLARS')
elif IN.upper() == "DOLLAR" and OUT.upper() == "DONISH KRONA":
    convert = AMOUNT * 6.27
    print(f'{convert} DONISH KRONA')
elif IN.upper() == "DONISH KRONA" and OUT.upper() == "DOLLAR":
    convert = AMOUNT / 6.27
    print(f'{convert} DOLLARS')
elif IN.upper() == "EURO" and OUT.upper() == "DOLLAR":
    convert = AMOUNT * 1.82
    print(f'{convert} DOLLARS')
elif IN.upper() == "DOLLAR" and OUT.upper() == "EURO":
    convert = AMOUNT / 1.82
    print(f'{convert} EURO')
elif IN.upper() == "DOLLAR" and OUT.upper() == "YEN":
    convert = AMOUNT / 0.0091
    print(f'{convert} YEN')
elif IN.upper() == "YEN" and OUT.upper() == "DOLLAR":
    convert = AMOUNT / 0.0091
    print(f'{convert} DOLLAR')
elif IN.upper() == "DOLLAR" and OUT.upper() == "SARAND":
    convert = AMOUNT / 14.60
    print(f'{convert} SARAND')
elif IN.upper() == "SARAND" and OUT.upper() == "DOLLAR":
    convert = AMOUNT / 14.60
    print(f'{convert} DOLLAR')
else: 
    print("WE DO NOT HAVE THAT CONVERTER AT THIS TIME")
print("THANKS FOR USING MY CONVERTER")
# Out:
# ================Welcome to my currency converter================
# ================Here are the list of currency you can convert into================
# ['USD Dollar', 'Naira', 'Euro', 'pounds', 'Yen', 'Swiss Franc', 'SDR', 'Waua', 'Riyal', 'SARand', 'Danish Krona']
# Enter the currency you are converting from: dollar
# Enter the currency you want into: naira
# Enter The Amount: 69
# 28290 NAIRA
# THANKS FOR USING MY CONVERTER
